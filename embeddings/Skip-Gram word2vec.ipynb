# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:10, 2.95MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
# Out:
# 'anarchism'

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
int_to_vocab[1]
# Out:
# 'of'

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
p_drop
train_words = [word for word in int_words if p_drop[word] < random.random()]
print(len(train_words))
# Out:
# 4628103

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %%
test_words = [i for i in range(30)]
get_target(test_words, 28)
# Out:
# [23, 24, 25, 26, 27, 29]

# %%
test_words[28:33]
# Out:
# [28, 29]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
batch = get_batches(test_words, 3)
for x, y in batch:
    print(x, y)
# Out:
# [0, 0, 1, 1, 2, 2] [1, 2, 0, 2, 0, 1]
# [3, 3, 4, 4, 5] [4, 5, 3, 5, 4]
# [6, 6, 7, 7, 8, 8] [8, 7, 8, 6, 6, 7]
# [9, 9, 10, 10, 11, 11] [10, 11, 9, 11, 9, 10]
# [12, 13, 13, 14, 14] [13, 12, 14, 12, 13]
# [15, 15, 16, 16, 17, 17] [16, 17, 17, 15, 16, 15]
# [18, 18, 19, 19, 20] [19, 20, 18, 20, 19]
# [21, 21, 22, 22, 23, 23] [22, 23, 21, 23, 21, 22]
# [24, 25, 25, 26, 26] [25, 24, 26, 24, 25]
# [27, 27, 28, 28, 29, 29] [28, 29, 27, 29, 27, 28]

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, 
                                      softmax_b, 
                                      labels, 
                                      embed, 
                                      n_sampled,
                                      n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6523 0.3876 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5922 0.3706 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4811 0.3948 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5979 0.3963 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5027 0.3940 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5243 0.3764 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5542 0.3886 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5434 0.3777 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4693 0.3835 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4298 0.3646 sec/batch
# Nearest to on: mourning, istv, drummer, octavius, examiners, pais, assaults, chaldees,
# Nearest to will: coils, sickness, bgn, carroll, ones, depardieu, sforza, creators,
# Nearest to for: cede, aichi, one, perceives, clitoris, bodo, sherpa, nile,
# Nearest to had: policymakers, carelessness, afoul, schulz, portuguesa, encyclopedists, yttrium, ccir,
# Nearest to as: bahar, agha, fielded, harper, hyrum, rift, cerebellar, ink,
# Nearest to and: synge, attorney, mihai, embarrassment, norodom, nutrient, watcher, abused,
# Nearest to were: tuxedo, pietist, operator, heaps, mineralogy, communicating, bands, inshore,
# Nearest to all: falsifying, wien, closest, winter, dodger, giants, persist, cheque,
# Nearest to bible: increases, stout, salutary, whitehall, refuges, nye, barrelled, worden,
# Nearest to channel: trajan, brussels, influence, neustadt, skilful, condominium, cug, diving,
# Nearest to orthodox: contemplative, laes, microbats, shells, blowout, eastbourne, tut, ghidorah,
# Nearest to centre: folic, hypertrophy, hilbert, bonaparte, salutary, pump, unscr, cavour,
# Nearest to paris: bana, cathedral, directional, reiner, aftermath, digging, incarceration, keats,
# Nearest to taking: morea, looped, legrand, boniface, dramatised, usr, infallible, refuelling,
# Nearest to pre: instabilities, guys, mining, umar, punic, sound, savoie, haut,
# Nearest to troops: pvp, approximated, essences, dail, budo, swordsman, robards, adopted,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4940 0.3749 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3689 0.3769 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3556 0.3802 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2339 0.3744 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1559 0.3541 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1810 0.3537 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0778 0.3537 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0544 0.3577 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0026 0.3534 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9767 0.3562 sec/batch
# Nearest to on: mourning, drummer, contemporary, examiners, iran, fermat, relatively, software,
# Nearest to will: coils, ones, sickness, total, creators, countries, complement, redesigned,
# Nearest to for: one, cede, involve, nile, perceives, december, perry, flesh,
# Nearest to had: policymakers, carelessness, stated, dozen, numbers, afoul, schulz, such,
# Nearest to as: harper, bands, rift, out, fielded, ink, agha, combinations,
# Nearest to and: essence, attorney, defined, abused, self, sequences, synge, germany,
# Nearest to were: operator, pietist, tuxedo, bands, up, communicating, closely, mineralogy,
# Nearest to all: closest, falsifying, winter, sound, wien, persist, dodger, giants,
# Nearest to bible: increases, stout, salutary, whitehall, barrelled, gorge, waxes, nye,
# Nearest to channel: influence, informa, brussels, slight, trajan, neustadt, dissenters, leviathan,
# Nearest to orthodox: shells, blowout, contemplative, laes, tone, ir, solar, microbats,
# Nearest to centre: folic, hilbert, pump, bonaparte, traveling, hypertrophy, venezuelan, salutary,
# Nearest to paris: cathedral, believes, entity, bana, effecting, directional, venezuela, operate,
# Nearest to taking: morea, infallible, physically, scholarship, atmospheric, systems, looped, compliance,
# Nearest to pre: instabilities, mining, sound, guys, justice, sensitivity, punic, aged,
# Nearest to troops: adopted, approximated, pvp, them, authorized, while, participants, essences,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9410 0.3601 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8939 0.3533 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8817 0.3565 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8782 0.3546 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8164 0.3559 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8067 0.3611 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7863 0.3841 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7783 0.3809 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7704 0.3755 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7734 0.3574 sec/batch
# Nearest to on: mourning, drummer, istv, examiners, assaults, reproducing, contemporary, iran,
# Nearest to will: coils, sickness, ones, bgn, creators, amplitudes, complement, perimeter,
# Nearest to for: cede, one, nile, perceives, involve, perry, hanoi, december,
# Nearest to had: policymakers, carelessness, thanks, dozen, stated, afoul, enhance, encyclopedists,
# Nearest to as: harper, bands, rift, out, traders, interred, eng, carleton,
# Nearest to and: essence, synge, attorney, embarrassment, germany, abused, zinc, nutrient,
# Nearest to were: pietist, tuxedo, operator, bands, proposals, up, communicating, fails,
# Nearest to all: falsifying, winter, closest, persist, wien, sound, dodger, cheque,
# Nearest to bible: increases, stout, whitehall, glory, barrelled, gorge, salutary, collaborations,
# Nearest to channel: influence, brussels, trajan, neustadt, informa, slight, condominium, strengthen,
# Nearest to orthodox: shells, blowout, solar, contemplative, tone, laes, ir, microbats,
# Nearest to centre: bonaparte, folic, hilbert, pump, remorse, traveling, freeform, venezuelan,
# Nearest to paris: cathedral, effecting, directional, believes, aftermath, parentheses, segment, entity,
# Nearest to taking: atmospheric, morea, infallible, scholarship, boniface, usr, spent, systems,
# Nearest to pre: instabilities, guys, sound, mining, justice, aged, sensitivity, cooperation,
# Nearest to troops: pvp, approximated, adopted, authorized, participants, essences, tippett, rhine,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7817 0.3602 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7766 0.3548 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7115 0.3539 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6976 0.3522 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7602 0.3571 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6911 0.3551 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7197 0.3553 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7291 0.3539 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7020 0.3536 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6550 0.3531 sec/batch
# Nearest to on: mourning, assaults, drummer, istv, examiners, guillermo, venom, cyndi,
# Nearest to will: coils, sickness, ones, contracting, creators, bgn, perimeter, sforza,
# Nearest to for: cede, spacious, nile, hanoi, perceives, perry, clitoris, involve,
# Nearest to had: policymakers, afoul, dozen, carelessness, encyclopedists, thanks, devout, stated,
# Nearest to as: bands, harper, rift, agha, eng, out, carleton, exam,
# Nearest to and: essence, synge, attorney, germany, embarrassment, zinc, norodom, obtaining,
# Nearest to were: pietist, tuxedo, proposals, bands, communicating, parliament, prescribe, rai,
# Nearest to all: falsifying, winter, wien, persist, closest, dodger, sound, cheque,
# Nearest to bible: increases, stout, whitehall, salutary, barrelled, collaborations, kenyatta, glory,
# Nearest to channel: brussels, neustadt, trajan, influence, informa, condominium, skilful, cug,
# Nearest to orthodox: shells, contemplative, blowout, ir, popularization, marmara, solar, laes,
# Nearest to centre: folic, bonaparte, unscr, freeform, hilbert, remorse, salutary, bantu,
# Nearest to paris: cathedral, directional, aftermath, bana, effecting, venezuela, michel, believes,
# Nearest to taking: morea, infallible, atmospheric, boniface, usr, looped, legrand, boxes,
# Nearest to pre: instabilities, guys, ipv, mining, aged, sensitivity, cooperation, sound,
# Nearest to troops: authorized, swordsman, adopted, participants, pvp, approximated, lands, essences,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6613 0.3573 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6548 0.3535 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6131 0.3554 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6251 0.3543 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6319 0.3539 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6298 0.3577 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5897 0.2584 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5349 12.0694 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5147 0.4066 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5128 0.3922 sec/batch
# Nearest to on: istv, mourning, assaults, drummer, venom, parcel, examiners, pais,
# Nearest to will: coils, ones, sickness, contracting, determinate, perimeter, creators, conserve,
# Nearest to for: cede, spacious, salamis, accept, clitoris, phobos, involve, nile,
# Nearest to had: policymakers, dozen, afoul, devout, encyclopedists, stated, carelessness, thanks,
# Nearest to as: bands, dispenses, cerebellar, out, combinations, agha, rift, exam,
# Nearest to and: essence, synge, attorney, complicity, obtaining, zinc, wallach, embarrassment,
# Nearest to were: pietist, tuxedo, rai, foundered, luna, wavering, proposals, bands,
# Nearest to all: falsifying, wien, persist, winter, cheque, closest, dodger, sound,
# Nearest to bible: increases, stout, whitehall, nye, kenyatta, salutary, barrelled, waxes,
# Nearest to channel: neustadt, brussels, cug, trajan, stations, jumbo, influence, fairs,
# Nearest to orthodox: contemplative, blowout, popularization, shells, ir, laes, unimportant, marmara,
# Nearest to centre: bonaparte, folic, freeform, bantu, salutary, unscr, ogg, remorse,
# Nearest to paris: cathedral, bana, aftermath, directional, michel, mia, wootton, keats,
# Nearest to taking: morea, usr, atmospheric, looped, infallible, boniface, legrand, boxes,
# Nearest to pre: instabilities, ipv, haut, mining, guys, enid, sensitivity, aged,
# Nearest to troops: authorized, swordsman, adopted, lands, rhine, participants, robards, sowed,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5000 0.3682 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4701 0.3551 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4566 0.3541 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5161 0.3857 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4955 0.3689 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4699 0.3633 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4884 0.3603 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4088 0.3667 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4445 0.3957 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4475 0.3642 sec/batch
# Nearest to on: istv, parcel, mourning, drummer, assaults, pais, venom, lm,
# Nearest to will: coils, ones, sickness, determinate, contracting, perimeter, creators, microprocessors,
# Nearest to for: salamis, cede, spacious, accept, switches, are, variable, phobos,
# Nearest to had: policymakers, afoul, dozen, devout, thanks, encyclopedists, carelessness, stated,
# Nearest to as: out, bands, ndp, exam, cerebellar, combinations, agha, baasha,
# Nearest to and: essence, synge, zinc, wallach, obtaining, attorney, complicity, deactivated,
# Nearest to were: pietist, tuxedo, rai, wavering, autonomy, foundered, opportunities, luna,
# Nearest to all: falsifying, wien, cheque, persist, winter, closest, vendors, symbols,
# Nearest to bible: increases, stout, whitehall, glory, kenyatta, nye, barrelled, seagal,
# Nearest to channel: stations, brussels, neustadt, cug, trajan, floating, links, diving,
# Nearest to orthodox: popularization, sert, ir, contemplative, blowout, marmara, jewish, christian,
# Nearest to centre: freeform, bonaparte, ogg, east, remorse, folic, salutary, tapirs,
# Nearest to paris: cathedral, aftermath, bana, michel, encyclopedists, mia, wootton, romana,
# Nearest to taking: morea, usr, looped, infallible, boniface, atmospheric, dramatised, boxes,
# Nearest to pre: instabilities, ipv, aged, mining, haut, enid, cooperation, cadres,
# Nearest to troops: swordsman, authorized, lands, adopted, rhine, homing, sowed, robards,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4351 0.3737 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3922 0.3655 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4355 0.3585 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4005 0.3782 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4313 0.3795 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4295 0.3741 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4075 0.3796 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3787 0.3731 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4182 0.3753 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3950 0.3674 sec/batch
# Nearest to on: mourning, istv, drummer, pais, venom, parcel, assaults, examiners,
# Nearest to will: coils, perimeter, ones, sickness, creators, contracting, determinate, bgn,
# Nearest to for: spacious, salamis, cede, accept, perceives, ras, variable, bream,
# Nearest to had: policymakers, dozen, devout, afoul, stated, encyclopedists, ccir, thanks,
# Nearest to as: out, bands, exam, cerebellar, ndp, baasha, bahar, rift,
# Nearest to and: essence, synge, obtaining, wallach, deactivated, self, spelt, zinc,
# Nearest to were: pietist, tuxedo, rai, inshore, wavering, opportunities, teuton, foundered,
# Nearest to all: falsifying, wien, cheque, persist, symbols, closest, vendors, dodger,
# Nearest to bible: stout, glory, increases, whitehall, sola, nye, latin, who,
# Nearest to channel: stations, brussels, neustadt, cug, condominium, links, diving, godse,
# Nearest to orthodox: catholic, christian, sert, jewish, popularization, monophysite, catholicism, anointing,
# Nearest to centre: freeform, bonaparte, east, salutary, folic, suevi, ogg, remorse,
# Nearest to paris: cathedral, michel, bana, romana, reiner, outrageous, thoreau, wootton,
# Nearest to taking: morea, usr, looped, boniface, legrand, widowers, infallible, groupware,
# Nearest to pre: instabilities, ipv, aged, mining, haut, cadres, enid, groom,
# Nearest to troops: swordsman, authorized, rhine, lands, robards, adopted, addis, sowed,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3925 0.3824 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4170 0.4002 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3517 0.3830 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3580 0.3756 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4062 0.3935 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3614 0.3756 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3952 0.3855 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4062 0.3635 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3193 0.3582 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3181 0.3542 sec/batch
# Nearest to on: istv, mourning, venom, pais, assaults, parcel, abbreviating, cyndi,
# Nearest to will: coils, perimeter, sickness, creators, contracting, determinate, ones, improves,
# Nearest to for: variable, are, salamis, perceives, allocate, involve, cede, spacious,
# Nearest to had: policymakers, afoul, devout, dozen, stated, thanks, ccir, carelessness,
# Nearest to as: out, exam, cerebellar, bahar, ndp, bands, artisans, eng,
# Nearest to and: essence, obtaining, zinc, duna, multilateral, synge, self, germany,
# Nearest to were: pietist, tuxedo, rai, opportunities, inshore, wavering, alkenes, foundered,
# Nearest to all: falsifying, wien, symbols, closest, cheque, dodger, persist, mummification,
# Nearest to bible: stout, glory, latin, tanakh, sola, whitehall, nonetheless, tacit,
# Nearest to channel: stations, cug, broadcasting, neustadt, brussels, communications, programme, floating,
# Nearest to orthodox: catholic, christian, sert, orthodoxy, catholicism, popularization, jewish, anointing,
# Nearest to centre: freeform, bonaparte, east, folic, ogg, suevi, salutary, remorse,
# Nearest to paris: reiner, romana, bana, michel, thoreau, mia, cathedral, encyclopedists,
# Nearest to taking: morea, usr, looped, conspired, spent, issuing, spade, boniface,
# Nearest to pre: instabilities, aged, haut, mining, early, enid, cadres, ipv,
# Nearest to troops: rhine, lands, authorized, swordsman, sowed, adopted, nationalists, homing,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3429 0.3634 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2755 0.3660 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3789 0.3840 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3750 0.3693 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4121 0.3787 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2998 0.3895 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3018 0.3648 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3250 0.3633 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2255 0.3545 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2899 0.3536 sec/batch
# Nearest to on: istv, mourning, pais, venom, parcel, assaults, announced, cyndi,
# Nearest to will: perimeter, creators, coils, sickness, contracting, ones, direction, determinate,
# Nearest to for: spacious, are, allocate, salamis, variable, accept, tauranac, involve,
# Nearest to had: policymakers, dozen, afoul, devout, trieste, ccir, thanks, him,
# Nearest to as: baasha, out, bands, cerebellar, carleton, loc, dispenses, bahar,
# Nearest to and: obtaining, norodom, essence, self, duna, germany, thirdly, zinc,
# Nearest to were: pietist, tuxedo, inshore, opportunities, teuton, rai, gassing, alkenes,
# Nearest to all: falsifying, wien, cheque, symbols, persist, closest, dodger, eks,
# Nearest to bible: tanakh, stout, sola, glory, nonetheless, interpretations, seagal, dualist,
# Nearest to channel: stations, broadcasting, cug, neustadt, programme, communications, links, brussels,
# Nearest to orthodox: christian, catholic, catholicism, sert, orthodoxy, jewish, popularization, contemplative,
# Nearest to centre: freeform, east, ogg, suevi, bonaparte, mollymawks, salutary, folic,
# Nearest to paris: reiner, romana, bana, cathedral, ishtar, michel, thoreau, mia,
# Nearest to taking: morea, looped, usr, spent, conspired, legrand, spade, issuing,
# Nearest to pre: instabilities, haut, ipv, early, aged, mining, enid, beasley,
# Nearest to troops: rhine, authorized, lands, sowed, austrians, addis, adopted, robards,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3055 0.3623 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2827 0.3540 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3439 0.1568 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2701 0.3666 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2121 0.4230 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2440 0.3693 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2001 0.3552 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2041 0.3575 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2087 0.3538 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1827 0.3588 sec/batch
# Nearest to on: istv, mourning, announced, parcel, pais, assaults, drummer, venom,
# Nearest to will: perimeter, creators, coils, ones, improves, contracting, direction, determinate,
# Nearest to for: are, cede, accept, salamis, spacious, tauranac, allocate, variable,
# Nearest to had: policymakers, afoul, dozen, thanks, him, stated, seanad, ccir,
# Nearest to as: salient, out, baasha, cerebellar, bands, dispenses, sleepycat, eng,
# Nearest to and: obtaining, duna, germany, zinc, essence, dispel, self, lollard,
# Nearest to were: pietist, inshore, opportunities, gassing, tuxedo, teuton, rai, wavering,
# Nearest to all: falsifying, wien, dodger, cheque, symbols, closest, persist, fourths,
# Nearest to bible: tanakh, glory, sola, stout, vulgate, septuagint, nonetheless, historiographical,
# Nearest to channel: stations, broadcasting, cug, programme, chamber, brussels, ru, neustadt,
# Nearest to orthodox: catholicism, catholic, christian, hebrews, orthodoxy, sert, anointing, jewish,
# Nearest to centre: freeform, east, suevi, iowa, ogg, mollymawks, rail, confluence,
# Nearest to paris: reiner, ishtar, romana, mia, bana, cathedral, outrageous, encyclopedists,
# Nearest to taking: morea, usr, spent, looped, conspired, issuing, groupware, shoots,
# Nearest to pre: instabilities, haut, early, ipv, aged, cadres, viceroys, enid,
# Nearest to troops: authorized, sowed, rhine, clitoridectomy, austrians, fight, participants, forces,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2673 0.3644 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2439 0.3610 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2240 0.3563 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1186 0.3561 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1740 0.3530 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1956 0.3541 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1716 0.3513 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1749 0.3542 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2213 0.3555 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1993 0.3543 sec/batch
# Nearest to on: pais, announced, istv, drummer, mourning, venom, assaults, parcel,
# Nearest to will: perimeter, creators, improves, determinate, ones, coils, direction, misbehavior,
# Nearest to for: are, tauranac, allocate, variable, tailor, accept, stationary, is,
# Nearest to had: policymakers, afoul, him, thanks, dozen, devout, carelessness, decayed,
# Nearest to as: cerebellar, dispenses, sleepycat, eng, called, out, hyrum, baasha,
# Nearest to and: self, zinc, obtaining, essence, thirdly, using, dispel, indoors,
# Nearest to were: inshore, opportunities, rai, gassing, pietist, tuxedo, teuton, itasca,
# Nearest to all: falsifying, wien, cheque, closest, symbols, dodger, winter, vendors,
# Nearest to bible: tanakh, sola, vulgate, septuagint, glory, nonetheless, historiographical, whitehall,
# Nearest to channel: stations, broadcasting, programme, cug, brussels, television, ru, chamber,
# Nearest to orthodox: orthodoxy, catholic, catholicism, hebrews, christian, sert, anointing, denominations,
# Nearest to centre: freeform, iowa, suevi, east, ogg, mollymawks, intercity, confluence,
# Nearest to paris: reiner, ishtar, romana, mia, outrageous, bana, maceo, directional,
# Nearest to taking: morea, usr, looped, spent, shoots, issuing, conspired, groupware,
# Nearest to pre: instabilities, early, ipv, aged, haut, cadres, groom, viceroys,
# Nearest to troops: sowed, rhine, authorized, fight, austrians, addis, robards, fighting,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1628 0.3585 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2247 0.3541 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1875 0.3549 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1683 0.3536 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1726 0.3532 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2228 0.3558 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1910 0.3536 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1701 0.3586 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1530 0.3566 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1870 0.3582 sec/batch
# Nearest to on: pais, announced, istv, assaults, venom, mourning, changsha, cyndi,
# Nearest to will: perimeter, direction, determinate, creators, improves, backbench, ones, misbehavior,
# Nearest to for: are, tauranac, is, allocate, accept, rights, variable, perry,
# Nearest to had: policymakers, afoul, ccir, him, prez, dozen, thanks, stated,
# Nearest to as: cerebellar, sleepycat, jabir, eng, out, baasha, bands, combinations,
# Nearest to and: self, essence, zinc, dispel, obtaining, thirdly, germany, using,
# Nearest to were: inshore, gassing, opportunities, rai, itasca, tuxedo, teuton, pietist,
# Nearest to all: falsifying, wien, dodger, symbols, cheque, closest, fourths, vocabularies,
# Nearest to bible: sola, vulgate, tanakh, septuagint, translations, glory, passages, editions,
# Nearest to channel: stations, broadcasting, programme, cug, ru, brussels, television, krueger,
# Nearest to orthodox: orthodoxy, catholicism, catholic, hebrews, anointing, monophysite, sert, christian,
# Nearest to centre: freeform, suevi, iowa, ogg, intercity, east, mollymawks, confluence,
# Nearest to paris: romana, ishtar, reiner, maceo, outrageous, mia, michel, thoreau,
# Nearest to taking: morea, usr, spent, conspired, archdeacon, shoots, issuing, okavango,
# Nearest to pre: instabilities, early, ipv, aged, lacoste, groom, punic, viceroys,
# Nearest to troops: sowed, rhine, fight, authorized, austrians, forces, robards, pvp,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1995 2.5010 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1610 0.4076 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1830 0.3601 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1746 0.3745 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1555 0.3593 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1345 0.3541 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1468 0.3547 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1415 0.3572 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1880 0.3551 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2366 0.3628 sec/batch
# Nearest to on: announced, assaults, pais, changsha, mourning, cyndi, cry, istv,
# Nearest to will: perimeter, direction, creators, peal, determinate, misbehavior, backbench, improves,
# Nearest to for: are, is, tauranac, goldberg, perry, and, one, accept,
# Nearest to had: policymakers, afoul, dozen, him, ccir, devout, thanks, bangs,
# Nearest to as: cerebellar, fatherland, eng, jabir, baasha, unpatriotic, mentally, carleton,
# Nearest to and: self, dispel, with, minarchist, ves, jebusites, obtaining, essence,
# Nearest to were: opportunities, gassing, rai, pietist, inshore, teuton, itasca, nobles,
# Nearest to all: falsifying, wien, dodger, cheque, symbols, closest, ty, fourths,
# Nearest to bible: sola, vulgate, septuagint, tanakh, glory, whitehall, editions, historiographical,
# Nearest to channel: stations, broadcasting, programme, cug, godse, ru, krueger, wikis,
# Nearest to orthodox: orthodoxy, hebrews, catholicism, catholic, anointing, monophysite, sert, popularization,
# Nearest to centre: freeform, iowa, ogg, suevi, intercity, mollymawks, east, austen,
# Nearest to paris: romana, ishtar, outrageous, reiner, mia, maceo, natron, michel,
# Nearest to taking: morea, conspired, usr, spent, looped, legrand, boniface, shoots,
# Nearest to pre: instabilities, early, haut, enid, groom, viceroys, aged, lacoste,
# Nearest to troops: authorized, sowed, rhine, einsatzgruppen, forces, fight, robards, austrians,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2228 0.3602 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1537 0.3544 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1193 0.3524 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1332 0.3530 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0289 0.3549 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1408 0.3567 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1574 0.3541 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1474 0.3546 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1755 0.0577 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1267 0.3538 sec/batch
# Nearest to on: announced, assaults, is, pais, parcel, mourning, istv, cyndi,
# Nearest to will: perimeter, direction, creators, improves, determinate, peal, ones, misbehavior,
# Nearest to for: are, and, goldberg, is, tauranac, mede, stationary, one,
# Nearest to had: policymakers, ccir, afoul, dozen, him, carelessness, decayed, thanks,
# Nearest to as: cerebellar, jabir, baasha, dispenses, combinations, called, bands, wied,
# Nearest to and: with, self, zinc, using, ves, jebusites, germany, obtaining,
# Nearest to were: gassing, opportunities, inshore, teuton, pietist, agape, nobles, soon,
# Nearest to all: falsifying, wien, dodger, cheque, winter, closest, symbols, fourths,
# Nearest to bible: sola, tanakh, vulgate, septuagint, whitehall, editions, capra, glory,
# Nearest to channel: stations, broadcasting, programme, pbs, cug, television, krueger, wikis,
# Nearest to orthodox: orthodoxy, catholic, hebrews, catholicism, anointing, sert, monophysite, popularization,
# Nearest to centre: freeform, iowa, intercity, suevi, ogg, mollymawks, east, rail,
# Nearest to paris: ishtar, romana, mia, michel, maceo, reiner, du, outrageous,
# Nearest to taking: morea, conspired, usr, legrand, issuing, spent, degenerated, shoots,
# Nearest to pre: early, instabilities, enid, haut, groom, ipv, mining, lacoste,
# Nearest to troops: authorized, rhine, einsatzgruppen, austrians, sowed, forces, robards, fight,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0791 0.3609 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0511 0.3587 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1087 19.2566 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0676 0.4213 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0855 0.3803 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0491 0.3569 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0835 0.3569 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0799 0.3567 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1255 0.3580 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0201 0.3643 sec/batch
# Nearest to on: announced, mourning, is, drummer, pais, technician, parcel, changsha,
# Nearest to will: perimeter, direction, peal, creators, determinate, expected, improves, backbench,
# Nearest to for: are, is, denard, tauranac, and, one, curried, tailor,
# Nearest to had: policymakers, ccir, afoul, him, decayed, dozen, thanks, satisfied,
# Nearest to as: cerebellar, called, eng, referred, jabir, baasha, combinations, dispenses,
# Nearest to and: with, self, zinc, jebusites, dispel, germany, using, spurs,
# Nearest to were: gassing, teuton, opportunities, inshore, soon, nobles, rai, itasca,
# Nearest to all: falsifying, wien, dodger, cheque, symbols, closest, winter, fourths,
# Nearest to bible: sola, vulgate, tanakh, septuagint, translations, nevi, editions, aryeh,
# Nearest to channel: stations, broadcasting, programme, television, cug, viewers, pbs, wikis,
# Nearest to orthodox: catholic, orthodoxy, anointing, catholicism, hebrews, sert, monophysite, popularization,
# Nearest to centre: freeform, intercity, suevi, iowa, ogg, headquarters, mollymawks, confluence,
# Nearest to paris: ishtar, romana, directional, michel, mia, du, natron, reiner,
# Nearest to taking: morea, usr, shoots, archdeacon, conspired, then, spent, degenerated,
# Nearest to pre: early, instabilities, haut, enid, groom, lacoste, frustrations, cadres,
# Nearest to troops: forces, sowed, fight, einsatzgruppen, rhine, austrians, robards, clitoridectomy,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0210 0.3686 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0466 0.3669 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0187 0.3535 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0565 0.3552 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0843 0.3553 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0790 0.3563 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0545 0.3572 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0955 0.3571 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0648 0.3563 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0435 0.3565 sec/batch
# Nearest to on: announced, is, pais, cyndi, venom, changsha, parcel, assaults,
# Nearest to will: perimeter, direction, peal, determinate, creators, expected, improves, ones,
# Nearest to for: are, is, one, and, tauranac, goldberg, denard, stationary,
# Nearest to had: policymakers, afoul, decayed, ccir, were, satisfied, prez, him,
# Nearest to as: cerebellar, called, eng, dispenses, jabir, subtraction, bands, combinations,
# Nearest to and: with, self, deconvolution, for, using, zinc, of, thirdly,
# Nearest to were: opportunities, gassing, inshore, teuton, soon, rai, had, nobles,
# Nearest to all: falsifying, wien, symbols, dodger, closest, cheque, winter, fourths,
# Nearest to bible: sola, vulgate, septuagint, tanakh, editions, translations, whitehall, aryeh,
# Nearest to channel: broadcasting, stations, programme, television, pbs, viewers, wikis, cug,
# Nearest to orthodox: orthodoxy, catholic, catholicism, monophysite, hebrews, anointing, scriptural, sert,
# Nearest to centre: freeform, intercity, suevi, iowa, confluence, manche, headquarters, ogg,
# Nearest to paris: romana, ishtar, du, michel, mia, maceo, directional, outrageous,
# Nearest to taking: morea, usr, then, conspired, degenerated, spent, shoots, legrand,
# Nearest to pre: early, instabilities, groom, lacoste, frustrations, haut, mining, punic,
# Nearest to troops: forces, austrians, rhine, einsatzgruppen, sowed, fight, addis, robards,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0548 0.3628 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1130 0.3581 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0697 0.3567 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0590 0.3545 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0977 0.3577 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0687 0.3595 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0774 0.3557 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0699 0.3599 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0778 0.3579 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0693 0.3759 sec/batch
# Nearest to on: announced, mourning, signatory, pais, changsha, is, cyndi, cry,
# Nearest to will: perimeter, peal, direction, creators, determinate, rumored, ones, expected,
# Nearest to for: are, and, tailor, is, denard, one, goldberg, means,
# Nearest to had: policymakers, were, afoul, ccir, decayed, prez, him, settled,
# Nearest to as: cerebellar, called, dispenses, pikemen, nowadays, eng, jabir, wied,
# Nearest to and: with, of, self, deconvolution, for, using, germany, but,
# Nearest to were: gassing, opportunities, soon, had, teuton, nobles, lombard, ss,
# Nearest to all: falsifying, wien, closest, symbols, dodger, winter, cheque, ty,
# Nearest to bible: sola, septuagint, vulgate, whitehall, tanakh, translations, nevi, readily,
# Nearest to channel: broadcasting, stations, programme, television, pbs, viewers, wikis, cug,
# Nearest to orthodox: orthodoxy, catholic, catholicism, anointing, monophysite, hebrews, sert, scriptural,
# Nearest to centre: freeform, intercity, suevi, iowa, manche, confluence, headquarters, evocative,
# Nearest to paris: michel, romana, du, mia, ishtar, natron, maceo, gda,
# Nearest to taking: morea, usr, conspired, then, archdeacon, okavango, legrand, parthenogenesis,
# Nearest to pre: early, instabilities, haut, mining, groom, enid, punic, lacoste,
# Nearest to troops: rhine, austrians, fight, forces, einsatzgruppen, sowed, clitoridectomy, addis,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0516 0.3770 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0225 0.3575 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0609 0.3539 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0644 0.3601 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0599 0.3575 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1348 0.3553 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1383 0.3554 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0402 0.3574 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0445 0.3555 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0408 0.3531 sec/batch
# Nearest to on: announced, signatory, is, assaults, cyndi, pais, blazon, interrelated,
# Nearest to will: perimeter, peal, direction, expected, creators, determinate, ones, rumored,
# Nearest to for: are, and, is, goldberg, one, trivially, curried, tauranac,
# Nearest to had: policymakers, monteagle, ccir, afoul, him, were, settled, dozen,
# Nearest to as: cerebellar, baasha, mpla, jabir, fatherland, nowadays, dispenses, subtraction,
# Nearest to and: with, germany, for, deconvolution, self, but, using, dispel,
# Nearest to were: teuton, opportunities, gassing, had, inshore, soon, nobles, pietist,
# Nearest to all: falsifying, wien, closest, dodger, winter, symbols, cheque, ty,
# Nearest to bible: sola, vulgate, tanakh, septuagint, whitehall, translations, aryeh, nevi,
# Nearest to channel: broadcasting, stations, programme, pbs, television, viewers, cug, wikis,
# Nearest to orthodox: orthodoxy, sert, monophysite, catholicism, anointing, hebrews, catholic, popularization,
# Nearest to centre: freeform, intercity, suevi, mollymawks, iowa, evocative, wilno, austen,
# Nearest to paris: michel, romana, du, mia, ishtar, maceo, outrageous, bastiat,
# Nearest to taking: morea, usr, conspired, then, legrand, parthenogenesis, shoots, gbagbo,
# Nearest to pre: early, instabilities, haut, enid, punic, mining, lacoste, groom,
# Nearest to troops: rhine, forces, austrians, einsatzgruppen, sowed, fight, clitoridectomy, robards,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0013 0.3605 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0123 0.3564 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0392 0.3571 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0399 0.3579 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0948 0.3567 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0424 70.8671 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9992 0.3729 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9718 0.3616 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0230 0.3576 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9766 0.3573 sec/batch
# Nearest to on: announced, july, signatory, is, mourning, cry, assaults, cyndi,
# Nearest to will: perimeter, peal, direction, determinate, ones, expected, creators, rumored,
# Nearest to for: and, are, allocate, goldberg, tailor, mede, payments, mong,
# Nearest to had: policymakers, were, him, ccir, decayed, satisfied, was, episkopos,
# Nearest to as: cerebellar, referred, called, mpla, jabir, baasha, nowadays, dispenses,
# Nearest to and: with, deconvolution, using, for, germany, but, dispel, most,
# Nearest to were: teuton, had, soon, gassing, opportunities, nobles, inshore, wavering,
# Nearest to all: falsifying, wien, winter, dodger, closest, ty, collapses, cheque,
# Nearest to bible: septuagint, vulgate, tanakh, sola, editions, whitehall, readily, stout,
# Nearest to channel: broadcasting, stations, pbs, viewers, television, programme, cug, lateral,
# Nearest to orthodox: orthodoxy, catholic, anointing, catholicism, sert, monophysite, popularization, hebrews,
# Nearest to centre: freeform, intercity, iowa, suevi, evocative, manche, kattegat, confluence,
# Nearest to paris: michel, du, romana, mia, ishtar, natron, maceo, gda,
# Nearest to taking: morea, usr, parthenogenesis, gbagbo, shoots, then, conspired, spent,
# Nearest to pre: early, instabilities, groom, haut, enid, punic, frustrations, lacoste,
# Nearest to troops: rhine, forces, sowed, fight, robards, austrians, clitoridectomy, addis,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9893 0.3980 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9409 0.4062 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0091 0.3832 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0406 0.3593 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0363 0.3569 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9957 0.3572 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8977 0.3568 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9516 0.3649 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9624 0.3570 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9582 0.3647 sec/batch
# Nearest to on: announced, signatory, july, pais, blazon, redesigns, navigable, is,
# Nearest to will: perimeter, peal, direction, determinate, expected, ones, if, misbehavior,
# Nearest to for: are, and, is, one, allocate, of, lockout, mong,
# Nearest to had: were, policymakers, ccir, decayed, afoul, satisfied, prudently, settled,
# Nearest to as: cerebellar, called, referred, the, a, baasha, traditional, mpla,
# Nearest to and: with, but, deconvolution, for, of, most, the, some,
# Nearest to were: teuton, had, gassing, opportunities, soon, inshore, wavering, nobles,
# Nearest to all: falsifying, wien, winter, closest, hypothyroidism, dodger, ty, symbols,
# Nearest to bible: vulgate, septuagint, tanakh, editions, books, readily, whitehall, sola,
# Nearest to channel: broadcasting, stations, viewers, television, pbs, programme, cug, wikis,
# Nearest to orthodox: orthodoxy, catholicism, catholic, anointing, sert, monophysite, scriptural, popularization,
# Nearest to centre: freeform, intercity, suevi, threshold, evocative, mollymawks, manche, iowa,
# Nearest to paris: michel, du, romana, mia, ishtar, normale, natron, maceo,
# Nearest to taking: morea, usr, shoots, parthenogenesis, conspired, archdeacon, gbagbo, nicholson,
# Nearest to pre: early, instabilities, groom, punic, and, frustrations, mining, enid,
# Nearest to troops: sowed, forces, fight, rhine, austrians, homing, maneuver, conscript,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9871 0.3620 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0139 0.3574 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9630 0.3579 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0327 0.3566 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0048 0.3586 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9892 0.3679 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0148 0.3561 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9909 0.3577 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9785 0.3589 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0013 0.3556 sec/batch
# Nearest to on: announced, signatory, pais, blazon, july, mullen, glossaries, cyndi,
# Nearest to will: perimeter, peal, direction, seek, ones, determinate, happiness, ll,
# Nearest to for: and, are, of, is, one, goldberg, mede, rights,
# Nearest to had: were, ccir, decayed, afoul, policymakers, returned, settled, prudently,
# Nearest to as: called, a, cerebellar, the, traditional, referred, subtraction, well,
# Nearest to and: with, for, deconvolution, but, of, using, the, self,
# Nearest to were: teuton, had, soon, opportunities, gassing, inshore, carina, pietist,
# Nearest to all: falsifying, wien, ty, symbols, that, dodger, closest, winter,
# Nearest to bible: vulgate, septuagint, tanakh, readily, sola, whitehall, editions, pastoral,
# Nearest to channel: broadcasting, stations, viewers, pbs, television, programme, cug, wikis,
# Nearest to orthodox: orthodoxy, catholic, catholicism, monophysite, sert, scriptural, voortrekkers, anointing,
# Nearest to centre: freeform, iowa, intercity, suevi, headquarters, manche, threshold, evocative,
# Nearest to paris: michel, romana, du, mia, ishtar, maceo, gda, bastiat,
# Nearest to taking: morea, usr, parthenogenesis, nicholson, shoots, spent, archdeacon, gbagbo,
# Nearest to pre: early, groom, instabilities, punic, mining, frustrations, impure, manipulators,
# Nearest to troops: sowed, fight, rhine, austrians, clitoridectomy, addis, einsatzgruppen, conscript,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9983 0.3645 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9781 0.3593 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9919 0.3571 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0039 0.3568 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0116 0.3593 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0184 0.3575 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0050 0.3560 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9677 0.3570 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9719 0.3570 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9990 0.3642 sec/batch
# Nearest to on: announced, signatory, july, blazon, in, pais, which, decommissioning,
# Nearest to will: perimeter, peal, ll, direction, determinate, seek, expected, happiness,
# Nearest to for: and, are, is, of, allocate, mede, buttons, goldberg,
# Nearest to had: settled, were, ccir, returned, was, policymakers, decayed, thanks,
# Nearest to as: the, a, called, referred, cerebellar, become, by, some,
# Nearest to and: with, the, of, for, but, deconvolution, major, in,
# Nearest to were: teuton, had, gassing, opportunities, soon, inshore, pietist, wavering,
# Nearest to all: falsifying, wien, symbols, closest, is, that, fourths, dodger,
# Nearest to bible: vulgate, tanakh, septuagint, whitehall, sola, readily, stout, deuterocanonical,
# Nearest to channel: broadcasting, stations, viewers, pbs, television, channels, programme, lateral,
# Nearest to orthodox: orthodoxy, catholic, catholicism, sert, monophysite, anointing, scriptural, fundamentalists,
# Nearest to centre: freeform, threshold, headquarters, intercity, evocative, austen, suevi, wilno,
# Nearest to paris: michel, romana, du, ishtar, mia, gda, natron, bastiat,
# Nearest to taking: morea, usr, conspired, nicholson, veitch, groupware, spent, kassa,
# Nearest to pre: early, groom, punic, mining, instabilities, of, enid, frustrations,
# Nearest to troops: fight, sowed, rhine, tippett, austrians, addis, conscript, clitoridectomy,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9834 0.3659 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0860 0.3583 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0393 0.3582 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0712 0.3572 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9434 0.3576 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9709 0.3551 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9710 0.3561 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9059 0.3578 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9885 0.3597 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9823 0.3606 sec/batch
# Nearest to on: announced, signatory, july, decommissioning, cry, lancastrian, the, mourning,
# Nearest to will: perimeter, peal, expected, ll, ones, backbench, seek, direction,
# Nearest to for: and, are, goldberg, of, buttons, lockout, is, mede,
# Nearest to had: settled, were, ccir, drover, decayed, was, remakes, dozen,
# Nearest to as: a, called, cerebellar, the, become, well, sometimes, referred,
# Nearest to and: with, but, the, for, of, using, major, ves,
# Nearest to were: teuton, had, soon, inshore, gassing, ss, carina, opportunities,
# ...
# Nearest to paris: michel, lagering, normale, france, bordeaux, directional, mulhouse, natron,
# Nearest to taking: morea, toner, boxes, tripartite, kassa, archdeacon, raft, vanity,
# Nearest to pre: early, groom, punic, enid, mining, impure, ulvaeus, frustrations,
# Nearest to troops: fight, forces, tippett, compound, ambushed, misty, addis, soldier,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8812 0.4012 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7569 0.3637 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8358 0.3607 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8177 0.3634 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8226 0.3739 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8521 0.3812 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8752 0.3653 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8423 0.3677 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8761 0.3665 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9341 0.3685 sec/batch
# Nearest to on: the, in, a, announced, to, which, of, with,
# Nearest to will: seek, peal, ll, happiness, upmarket, realize, to, lifeform,
# Nearest to for: and, the, with, a, of, are, in, one,
# Nearest to had: were, was, settled, claimed, already, became, rest, returned,
# Nearest to as: the, in, a, by, many, of, also, some,
# Nearest to and: the, a, of, with, for, in, from, only,
# Nearest to were: had, teuton, was, soon, inshore, been, patagonian, nowadays,
# Nearest to all: that, are, only, and, there, way, is, for,
# Nearest to bible: whitehall, tanakh, stout, update, books, bunyan, readily, glory,
# Nearest to channel: broadcasting, pbs, upn, channels, viewers, television, lateral, programme,
# Nearest to orthodox: orthodoxy, catholic, sert, ir, karelia, anointing, coptic, plaguing,
# Nearest to centre: threshold, volleyball, kattegat, affaire, headquarters, lintel, hilbert, evocative,
# Nearest to paris: michel, france, lagering, normale, directional, bordeaux, mulhouse, natron,
# Nearest to taking: morea, tripartite, toner, boxes, kassa, raft, gbagbo, usr,
# Nearest to pre: early, groom, punic, mining, ulvaeus, impure, manipulators, of,
# Nearest to troops: fight, soldier, tippett, misty, ambushed, compound, addis, army,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8257 0.3723 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8560 0.3605 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8653 0.3656 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8488 0.3765 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8439 0.3685 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9045 0.3747 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8919 0.3861 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8474 0.3753 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8894 0.3680 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8491 0.3704 sec/batch
# Nearest to on: in, the, of, a, which, an, to, with,
# Nearest to will: seek, peal, ll, reach, davidovsky, there, upmarket, thy,
# Nearest to for: and, of, are, the, with, in, a, is,
# Nearest to had: were, was, already, settled, claimed, became, returned, rest,
# Nearest to as: a, the, in, by, of, also, some, used,
# Nearest to and: the, of, a, with, for, in, from, only,
# Nearest to were: had, teuton, was, been, soon, ss, nowadays, patagonian,
# Nearest to all: only, that, are, for, there, and, is, most,
# Nearest to bible: whitehall, stout, update, readily, tanakh, bunyan, abjads, translations,
# Nearest to channel: broadcasting, pbs, channels, upn, viewers, television, lateral, nbc,
# Nearest to orthodox: orthodoxy, catholic, sert, coptic, anointing, ir, karelia, plaguing,
# Nearest to centre: threshold, headquarters, volleyball, kattegat, affaire, evocative, hilbert, albans,
# Nearest to paris: michel, france, bordeaux, lagering, normale, directional, mulhouse, natron,
# Nearest to taking: morea, tripartite, kassa, raft, toner, archdeacon, boxes, gbagbo,
# Nearest to pre: early, groom, punic, ulvaeus, impure, mining, enid, of,
# Nearest to troops: fight, army, soldier, ambushed, tippett, addis, compound, control,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8476 0.3886 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8680 0.3742 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8461 0.3838 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8314 0.3783 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8789 0.3871 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8546 0.3821 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9790 0.4014 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9132 0.4517 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9188 0.3867 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8206 0.3942 sec/batch
# Nearest to on: in, the, of, a, to, which, and, announced,
# Nearest to will: seek, there, peal, ll, eustace, happiness, to, davidovsky,
# Nearest to for: and, are, with, of, the, a, in, as,
# Nearest to had: was, were, claimed, settled, already, became, his, but,
# Nearest to as: the, a, in, by, of, some, and, for,
# Nearest to and: the, with, of, a, for, in, from, which,
# Nearest to were: had, teuton, was, been, soon, thousands, nowadays, patagonian,
# Nearest to all: that, and, only, are, there, for, example, most,
# Nearest to bible: whitehall, stout, update, tanakh, readily, bunyan, easton, abjads,
# Nearest to channel: broadcasting, channels, upn, pbs, viewers, lateral, television, nbc,
# Nearest to orthodox: orthodoxy, sert, catholic, karelia, ir, plaguing, anointing, federation,
# Nearest to centre: threshold, albans, headquarters, evocative, volleyball, affaire, erowid, kattegat,
# Nearest to paris: michel, france, lagering, normale, bordeaux, directional, natron, outrageous,
# Nearest to taking: morea, tripartite, kassa, toner, raft, gbagbo, boxes, at,
# Nearest to pre: early, groom, punic, ulvaeus, of, frustrations, mining, impure,
# Nearest to troops: army, fight, control, ambushed, soldier, misty, tippett, compound,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7814 0.4283 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8675 0.3909 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7593 0.3882 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8691 0.3722 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8448 0.3867 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8445 0.3636 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9298 0.1753 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8087 0.3699 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8184 0.3920 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8397 0.4144 sec/batch
# Nearest to on: in, a, the, to, of, announced, from, for,
# Nearest to will: seek, peal, there, ll, happiness, upmarket, penni, davidovsky,
# Nearest to for: and, with, a, of, the, are, in, as,
# Nearest to had: was, were, claimed, already, settled, his, but, he,
# Nearest to as: a, the, in, by, and, of, some, used,
# Nearest to and: of, the, a, with, in, for, from, only,
# Nearest to were: had, teuton, was, soon, been, nowadays, ss, ouverture,
# Nearest to all: that, and, only, are, there, more, is, for,
# Nearest to bible: whitehall, stout, update, abjads, books, tanakh, readily, easton,
# Nearest to channel: broadcasting, channels, upn, pbs, viewers, lateral, television, nbc,
# Nearest to orthodox: orthodoxy, catholic, sert, karelia, plaguing, ir, federation, ancyra,
# Nearest to centre: threshold, albans, headquarters, volleyball, evocative, kattegat, affaire, lintel,
# Nearest to paris: michel, france, normale, lagering, natron, bordeaux, directional, louis,
# Nearest to taking: toner, tripartite, kassa, raft, gbagbo, boxes, morea, archdeacon,
# Nearest to pre: early, groom, ulvaeus, punic, enid, frustrations, manipulators, mining,
# Nearest to troops: army, misty, ambushed, fight, tippett, authorized, soldier, addis,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8686 0.3867 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8083 0.3767 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8145 0.3687 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7854 0.3654 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8752 0.3724 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8471 0.4019 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8737 0.3963 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7532 0.4005 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8041 0.3709 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8242 0.3829 sec/batch
# Nearest to on: in, to, the, a, of, which, from, for,
# Nearest to will: seek, there, peal, to, ll, correct, happiness, exists,
# Nearest to for: and, the, a, of, are, in, with, is,
# Nearest to had: were, was, already, claimed, settled, became, in, but,
# Nearest to as: the, in, a, by, and, of, some, is,
# Nearest to and: the, of, with, a, for, in, from, as,
# Nearest to were: had, was, teuton, soon, been, ouverture, early, nowadays,
# Nearest to all: are, and, only, there, that, for, example, more,
# Nearest to bible: translations, stout, update, books, whitehall, tanakh, abjads, easton,
# Nearest to channel: broadcasting, channels, upn, pbs, viewers, television, lateral, nbc,
# Nearest to orthodox: orthodoxy, catholic, sert, karelia, plaguing, anointing, ancyra, coptic,
# Nearest to centre: threshold, albans, evocative, headquarters, volleyball, lintel, bureaucracy, kattegat,
# Nearest to paris: michel, france, lagering, normale, bordeaux, directional, natron, musique,
# Nearest to taking: toner, kassa, tripartite, archdeacon, morea, at, raft, gbagbo,
# Nearest to pre: early, groom, punic, ulvaeus, enid, of, mining, nine,
# Nearest to troops: army, fight, ambushed, soldier, misty, forces, tippett, addis,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7686 0.4066 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8358 0.3849 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8674 0.4063 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8415 0.3755 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8101 0.3689 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8996 0.3572 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8502 0.3572 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8022 0.3555 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8358 0.3550 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8499 0.3574 sec/batch
# Nearest to on: the, a, to, in, of, for, which, and,
# Nearest to will: seek, peal, ll, backbench, happiness, there, realize, penni,
# Nearest to for: and, the, of, a, with, are, in, is,
# Nearest to had: was, were, already, settled, claimed, became, returned, his,
# Nearest to as: the, a, in, by, of, some, and, also,
# Nearest to and: of, the, a, with, for, in, from, as,
# Nearest to were: had, been, teuton, was, soon, bj, early, nowadays,
# Nearest to all: are, and, there, that, only, for, example, considers,
# Nearest to bible: translations, stout, update, whitehall, easton, tanakh, abjads, books,
# Nearest to channel: broadcasting, channels, viewers, pbs, upn, television, lateral, nbc,
# Nearest to orthodox: orthodoxy, catholic, coptic, anointing, plaguing, sert, ancyra, procreation,
# Nearest to centre: threshold, evocative, albans, volleyball, erowid, affaire, headquarters, bureaucracy,
# Nearest to paris: michel, france, lagering, bordeaux, normale, musique, louis, sculptural,
# Nearest to taking: kassa, toner, tripartite, raft, morea, reggie, boxes, gbagbo,
# Nearest to pre: early, ulvaeus, groom, punic, mining, enid, manipulators, impure,
# Nearest to troops: soldier, misty, tippett, ambushed, army, compound, addis, fight,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8725 0.3635 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8248 0.3561 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8287 0.3601 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8541 0.3563 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8675 0.3569 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8225 0.3603 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8283 0.3558 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8591 0.3588 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7940 0.3577 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8419 0.3563 sec/batch
# Nearest to on: the, in, a, to, of, which, and, for,
# Nearest to will: seek, peal, ll, there, penni, stf, davidovsky, to,
# Nearest to for: and, a, are, of, the, is, with, in,
# Nearest to had: were, was, already, settled, claimed, became, but, rest,
# Nearest to as: the, in, a, by, some, of, and, is,
# Nearest to and: the, of, a, with, in, for, from, as,
# Nearest to were: had, been, was, teuton, soon, thousands, nowadays, early,
# Nearest to all: and, are, that, there, only, for, many, example,
# Nearest to bible: stout, whitehall, easton, update, abjads, translations, tanakh, bunyan,
# Nearest to channel: broadcasting, channels, viewers, television, upn, pbs, lateral, nbc,
# Nearest to orthodox: orthodoxy, catholic, sert, anointing, coptic, reunite, plaguing, karelia,
# Nearest to centre: threshold, erowid, albans, evocative, bureaucracy, volleyball, polytechnics, headquarters,
# Nearest to paris: michel, france, lagering, bordeaux, natron, normale, musique, sculptural,
# Nearest to taking: toner, kassa, tripartite, at, morea, raft, reggie, gbagbo,
# Nearest to pre: early, punic, ulvaeus, groom, of, mining, th, which,
# Nearest to troops: army, ambushed, soldier, misty, tippett, servilius, fight, addis,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8475 0.3626 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8145 0.3621 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8957 0.3564 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9121 0.3560 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9018 0.3537 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8514 0.3543 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7662 0.3550 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8227 0.3528 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7386 0.3551 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8619 0.3574 sec/batch
# Nearest to on: in, a, to, the, of, and, is, which,
# Nearest to will: seek, ll, peal, there, davidovsky, stf, penni, to,
# Nearest to for: and, a, with, of, the, in, are, s,
# Nearest to had: was, were, claimed, settled, already, but, in, rest,
# Nearest to as: the, a, in, by, some, and, for, also,
# Nearest to and: a, the, of, with, for, in, from, which,
# Nearest to were: had, been, was, soon, teuton, nowadays, ss, bj,
# Nearest to all: and, are, that, only, there, for, considers, more,
# Nearest to bible: stout, update, whitehall, easton, translations, bunyan, abjads, books,
# Nearest to channel: broadcasting, channels, upn, viewers, pbs, lateral, television, nbc,
# Nearest to orthodox: orthodoxy, catholic, sert, coptic, karelia, reunite, anointing, plaguing,
# Nearest to centre: threshold, albans, evocative, checksum, erowid, volleyball, affaire, kattegat,
# Nearest to paris: michel, france, lagering, bordeaux, louis, natron, beefheart, outrageous,
# Nearest to taking: toner, kassa, at, tripartite, reggie, gbagbo, morea, austerlitz,
# Nearest to pre: early, ulvaeus, punic, groom, enid, mining, manipulators, introverted,
# Nearest to troops: misty, ambushed, army, tippett, soldier, addis, compound, forces,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8330 0.3595 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8356 0.3552 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-a4718e25bc97> in <module>()
#       1 viz_words = 500
#       2 tsne = TSNE()
# ----> 3 embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     864             Embedding of the training data in low-dimensional space.
#     865         """
# --> 866         embedding = self._fit(X)
#     867         self.embedding_ = embedding
#     868         return self.embedding_
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     775                           X_embedded=X_embedded,
#     776                           neighbors=neighbors_nn,
# --> 777                           skip_num_points=skip_num_points)
#     778
#     779     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     830         opt_args['momentum'] = 0.8
#     831         opt_args['it'] = it + 1
# --> 832         params, error, it = _gradient_descent(obj_func, params, **opt_args)
#     833         if self.verbose:
#     834             print("[t-SNE] Error after %d iterations with early "
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     385     for i in range(it, n_iter):
#     386         new_error, grad = objective(p, *args, **kwargs)
# --> 387         grad_norm = linalg.norm(grad)
#     388
#     389         inc = update * grad >= 0.0
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/craig/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
